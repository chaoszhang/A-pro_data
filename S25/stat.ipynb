# %%
# %matplotlib inline
import math
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 8]

cat = []
val = []
vcat = [[] for i in range(50)]
with open("../e4_0_70_ils.stat", "r") as ins:
    n = 0
    for line in ins:
        arr = line.split()
        if len(arr) > 2 and int(arr[0]) >= 12:
            cat.append(math.floor(n/1000))
            val.append(float(arr[2]) * 100)
            vcat[int(math.floor(n/1000))].append(float(arr[2]) * 100)
        n = n + 1
#print [np.mean(l) for l in vcat]
#print max([np.mean(l) for l in vcat]), min([np.mean(l) for l in vcat])
#print max(val), min(val)
plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0)
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
plt.xlabel("Replicates")
plt.ylabel("Distribution of genetree ILS level (%)")
plt.savefig("default_ils.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.rcParams['figure.figsize'] = [20, 16]
plt.subplot(2, 1, 1)
cat = []
val = []
vcat = [[] for i in range(50)]
h = []
with open("../default_duploss.stat", "r") as ins:
    for line in ins:
        arr = line.split()
        cat.append(int(arr[0])-1)
        val.append(int(arr[1]))
        h.append("Duplication")
        cat.append(int(arr[0])-1)
        val.append(int(arr[2]))
        h.append("Loss")
        vcat[int(arr[0])-1].append(int(arr[1]))
plot = sns.violinplot(x=cat, y=val, hue=h, order=np.argsort([np.mean(l) for l in vcat]), cut=0, split=True, inner="quartile")
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
#plt.xlabel("Replicates")
plt.ylabel("Distribution of # of duplication and loss events in genetrees")
plt.subplot(2, 1, 2)
cat = []
val = []
vcat = [[] for i in range(50)]
h = []
with open("../default_duploss.stat", "r") as ins:
    for line in ins:
        arr = line.split()
        cat.append(int(arr[0])-1)
        val.append(int(arr[3]))
        vcat[int(arr[0])-1].append(int(arr[3]))
plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0)
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
plt.xlabel("Replicates")
plt.ylabel("Distribution of # of leaves in genetrees")

plt.savefig("default_duploss.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.rcParams['figure.figsize'] = [20, 8]
cat = []
val = []
vcat = [[] for i in range(50)]
h = []
with open("../default_gte.stat", "r") as ins:
    for line in ins:
        arr = line.split()
        cat.append(int(arr[0])-1)
        val.append(float(arr[4])*100)
        h.append("100")
        cat.append(int(arr[0])-1)
        val.append(float(arr[7])*100)
        h.append("500")
        vcat[int(arr[0])-1].append(float(arr[4])*100)
plot = sns.violinplot(x=cat, y=val, hue=h, order=np.argsort([np.mean(l) for l in vcat]), cut=0, split=True, inner="quartile")
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
plt.xlabel("Replicates")
plt.ylabel("Distribution of genetree error (%)")
plt.savefig("default_gte.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.rcParams['figure.figsize'] = [20, 8]
cat = []
val = []
vcat = [[] for i in range(50)]
h = []
with open("../default_duploss.stat", "r") as ins:
    for line in ins:
        arr = line.split()
        cat.append(int(arr[0])-1)
        val.append(int(arr[1]))
        h.append("Duplication")
        cat.append(int(arr[0])-1)
        val.append(int(arr[2]))
        h.append("Loss")
        vcat[int(arr[0])-1].append(int(arr[1]))
plot = sns.violinplot(x=cat, y=val, hue=h, order=np.argsort([np.mean(l) for l in vcat]), cut=0, split=True, inner="quartile")
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
#plt.xlabel("Replicates")
plt.ylabel("Distribution of # of duplication and loss events in genetrees")
plt.savefig("default_duploss_only.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
cat = []
val = []
vcat = [[] for i in range(50)]
h = []
with open("../default_duploss.stat", "r") as ins:
    for line in ins:
        arr = line.split()
        cat.append(int(arr[0])-1)
        val.append(int(arr[3]))
        vcat[int(arr[0])-1].append(int(arr[3]))
plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0)
#plot.axes.get_xaxis().set_visible(False)
plot.axes.get_xaxis().set_ticks([])
plt.xlabel("Replicates")
plt.ylabel("Distribution of # of leaves in genetrees")

plt.savefig("default_leaves.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.rcParams['figure.figsize'] = [40, 10]

fig, axs = plt.subplots(4, 4, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})
fig.suptitle('Distribution of # duplication events in genetrees', y=0.1)

files = ["e3_02_0/duploss.stat", "e3_02_01/duploss.stat", "e3_02_05/duploss.stat", "e3_02_1/duploss.stat", "e3_1_0/duploss.stat", "e3_1_01/duploss.stat", "e3_1_05/duploss.stat", "e3_1_1/duploss.stat", "e3_2_0/duploss.stat", "e3_2_01/duploss.stat", "e3_2_05/duploss.stat", "e3_2_1/duploss.stat", "e3_5_0/duploss.stat", "e3_5_01/duploss.stat", "e3_5_05/duploss.stat", "default_duploss.stat"]
for y in range(4):
    for x in range(4):
        cat = []
        val = []
        vcat = [[] for i in range(50)]
        with open("../" + files[y * 4 + x], "r") as ins:
            for line in ins:
                arr = line.split()
                if len(arr) > 3:
                    cat.append(int(arr[0]) - 1)
                    val.append(float(arr[1]))
                    vcat[int(arr[0]) - 1].append(float(arr[1]))
        plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0, ax=axs[y, x], inner=None)
        plot.axes.get_xaxis().set_ticks([])
axs[3,0].set_xlabel("loss/dup=0")
axs[3,1].set_xlabel("loss/dup=0.1")
axs[3,2].set_xlabel("loss/dup=0.5")
axs[3,3].set_xlabel("loss/dup=1")
axs[0,0].set_ylabel("dup=0.2")
axs[1,0].set_ylabel("dup=1")
axs[2,0].set_ylabel("dup=2")
axs[3,0].set_ylabel("dup=5")
plt.savefig("e3_dup.pdf", bbox_inches = 'tight', pad_inches = 0)
fig, axs = plt.subplots(4, 4, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})
fig.suptitle('Distribution of # loss events in genetrees', y=0.1)

files = ["e3_02_0/duploss.stat", "e3_02_01/duploss.stat", "e3_02_05/duploss.stat", "e3_02_1/duploss.stat", "e3_1_0/duploss.stat", "e3_1_01/duploss.stat", "e3_1_05/duploss.stat", "e3_1_1/duploss.stat", "e3_2_0/duploss.stat", "e3_2_01/duploss.stat", "e3_2_05/duploss.stat", "e3_2_1/duploss.stat", "e3_5_0/duploss.stat", "e3_5_01/duploss.stat", "e3_5_05/duploss.stat", "default_duploss.stat"]
for y in range(4):
    for x in range(4):
        cat = []
        val = []
        vcat = [[] for i in range(50)]
        with open("../" + files[y * 4 + x], "r") as ins:
            for line in ins:
                arr = line.split()
                if len(arr) > 3:
                    cat.append(int(arr[0]) - 1)
                    val.append(float(arr[2]))
                    vcat[int(arr[0]) - 1].append(float(arr[2]))
        plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0, ax=axs[y, x], inner=None)
        plot.axes.get_xaxis().set_ticks([])
axs[3,0].set_xlabel("loss/dup=0")
axs[3,1].set_xlabel("loss/dup=0.1")
axs[3,2].set_xlabel("loss/dup=0.5")
axs[3,3].set_xlabel("loss/dup=1")
axs[0,0].set_ylabel("dup=0.2")
axs[1,0].set_ylabel("dup=1")
axs[2,0].set_ylabel("dup=2")
axs[3,0].set_ylabel("dup=5")
plt.savefig("e3_loss.pdf", bbox_inches = 'tight', pad_inches = 0)
fig, axs = plt.subplots(4, 4, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})
fig.suptitle('Distribution of # leaves in genetrees', y=0.1)

files = ["e3_02_0/duploss.stat", "e3_02_01/duploss.stat", "e3_02_05/duploss.stat", "e3_02_1/duploss.stat", "e3_1_0/duploss.stat", "e3_1_01/duploss.stat", "e3_1_05/duploss.stat", "e3_1_1/duploss.stat", "e3_2_0/duploss.stat", "e3_2_01/duploss.stat", "e3_2_05/duploss.stat", "e3_2_1/duploss.stat", "e3_5_0/duploss.stat", "e3_5_01/duploss.stat", "e3_5_05/duploss.stat", "default_duploss.stat"]
for y in range(4):
    for x in range(4):
        cat = []
        val = []
        vcat = [[] for i in range(50)]
        with open("../" + files[y * 4 + x], "r") as ins:
            for line in ins:
                arr = line.split()
                if len(arr) > 3:
                    cat.append(int(arr[0]) - 1)
                    val.append(float(arr[3]))
                    vcat[int(arr[0]) - 1].append(float(arr[3]))
        plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0, ax=axs[y, x], inner=None)
        plot.axes.get_xaxis().set_ticks([])
axs[3,0].set_xlabel("loss/dup=0")
axs[3,1].set_xlabel("loss/dup=0.1")
axs[3,2].set_xlabel("loss/dup=0.5")
axs[3,3].set_xlabel("loss/dup=1")
axs[0,0].set_ylabel("dup=0.2")
axs[1,0].set_ylabel("dup=1")
axs[2,0].set_ylabel("dup=2")
axs[3,0].set_ylabel("dup=5")
#axs[1].set_ylabel("Distribution of genetree ILS level (%)")
#axs[2,2].set_xlabel("Replicates")
#axs[0,1].set_ylabel("Distribution of # of leaves in genetrees")
plt.savefig("e3_leaf.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.rcParams['figure.figsize'] = [20, 12]
fig, axs = plt.subplots(3, 1, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0.1, 'wspace': 0})
#fig.suptitle('Sharing x per column, y per row')

files = ["../e4_0_20/ils.stat", "../e4_0_50/ils.stat", "../e4_0_70/ils.stat"]
for y in range(3):
    for x in range(1):
        cat = []
        val = []
        vcat = [[] for i in range(50)]
        with open(files[y], "r") as ins:
            for line in ins:
                arr = line.split()
                if len(arr) > 3:
                    cat.append(int(arr[0]) - 1)
                    val.append(float(arr[3]) * 100)
                    vcat[int(arr[0]) - 1].append(float(arr[3]) * 100)
        plot = sns.violinplot(x=cat, y=val, order=np.argsort([np.mean(l) for l in vcat]), cut=0, ax=axs[y], inner="quartile")
        plot.axes.get_xaxis().set_ticks([])
axs[0].set_title('20% ILS')
axs[1].set_title('50% ILS')
axs[2].set_title('70% ILS')
axs[2].set_xlabel("Replicates")
axs[1].set_ylabel("Distribution of genetree ILS level (%)")
#axs[2,2].set_xlabel("Replicates")
#axs[0,1].set_ylabel("Distribution of # of leaves in genetrees")
plt.savefig("e4_ils.pdf", bbox_inches = 'tight', pad_inches = 0)
